# %%
import numpy as np
import pandas as pd
import re
import pytesseract
import cv2
import matplotlib.pyplot as plt
from PIL import Image
import os

# %%
def ExtractDetails(image_path):
    text = pytesseract.image_to_string(Image.open(image_path), lang = 'eng')
    print(text)
    text = text.replace('\n', " ")
    text = text.replace('  '," ")
    regex_expdate = re.compile('EXP.\d{2}[-/]\d{4}')

    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    plt.imshow(image)
    plt.axis('off')

    if len(regex_expdate.findall(text)) == 0:
        print(f'Blurry Image for tesseract please upload a new one')
    else:
        text = regex_expdate.findall(text)
        print(text)

# %%
ExtractDetails('sample.jpeg')
# Out:
# sn
#
# | i Wr ss
# on 90 Ey
# a og ’ 3 3
# —_ 2 . 7 3
# oS 7
# me
# ©
# g 259490
#
#
#
# BA ' ee omeiea DATE ae
#
#
#
# Blurry Image for tesseract please upload a new one

# %%
ExtractDetails('sample2.jpeg')
# Out:
# B.No-CDZ006 MF D.0372022 PRD 0972022
# EXP.02/2025 M.R.P.Rs.686.00 FOR 30 TABS.
# INCL.OF ALL TAXES
#
# ['EXP.02/2025']

# %%
ExtractDetails('sample3.jpeg')
# Out:
# 0.22441363
#
# 8.N
#
# MFG.05/2022 EXP.10/2024
# M.R.P. € 155-00/ 15 TABS.
# INCL. OF ALL TAXES
#
# ~ NR T eSoa l
#
# ['EXP.10/2024']

# %%
ExtractDetails('sample4.jpeg')
# Out:
#
#
# Blurry Image for tesseract please upload a new one

# %%
def ExtractDetails(image_path):
    text = pytesseract.image_to_string(Image.open(image_path), lang = 'eng')
    text = text.replace('\n', " ")
    text = text.replace('  '," ")
    print(text)
    regex_expdate = re.compile('EXP.\d{2}[-/]\d{4}')
    regex_expdate2 = re.compile('EXP.\d{2}[-/]\d{2}')
    regex_expdate3 = re.compile('EXP\.\d{2}/\d{4}')
    regex_expdate4 = re.compile('EXPIRY DATE \d{2}/\d{4}')
    regex_expdate5 = re.compile('Exp\.Date:\d{1,2}[A-Z]{3}\d{4}')
    regex_expdate6 = re.compile('Exp\.Date:\s*\d{1,2}(?:JAN|FEB|MAR|APR|MAY|JUN|JUL|AUG|SEP|OCT|NOV|DEC)\d{4}')
    regex_expdate7 = re.compile('EXP:\s*\d{1,2}/\d{1,2}/\d{2}')
    regex_expdate8 = re.compile('Exp\.\s*\d{1,2}/\d{4}')
    regex_expdate9 = re.compile('EXP\d{2}/\d{4}')
    regex_expdate10 = re.compile('Exp\.\s*Date\s*:\s*\d{2}-\d{4}')
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    plt.imshow(image)
    plt.axis('off')
    patterns = [regex_expdate, regex_expdate2, regex_expdate3, regex_expdate4, regex_expdate5, regex_expdate6, regex_expdate7, regex_expdate8, regex_expdate9, regex_expdate10]
    extracted_text = ''
    i = 0
    while i < len(patterns):
        extracted_text = patterns[i].findall(text)
        print(extracted_text)
        if len(extracted_text) != 0:
            break
        i += 1
    return extracted_text

# %%
print(ExtractDetails('sample2.jpeg'))
# Out:
# B.H0.CD2006 HFD.03/2022 PKD 09/2022 EXP.02/2025 H.R.P-Rs.686.00 FOR 30TRBS. lNCL-OF RLL TRXES
# ['EXP.02/2025']
# ['EXP.02/2025']

# %%
print(ExtractDetails('sample21.webp'))
# Out:
# EXP: 11/25/17
# []
# []
# []
# []
# []
# []
# ['EXP: 11/25/17']
# ['EXP: 11/25/17']

# %%
print(ExtractDetails('sample23.jpg'))
# Out:
# EHPIRﬁTIDH DQTE FUHT HFE§33uE33 E~WF E'GQEET EEE T E'EFDEE       3E. [Eta EFEGHI .. .rmHnnPn
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []

# %%
print(ExtractDetails('sample23.png'))
# Out:
# Lot: 0000005 50 Capsules Exp. 01/2000
# []
# []
# []
# []
# []
# []
# []
# ['Exp. 01/2000']
# ['Exp. 01/2000']

# %%
print(ExtractDetails('sample24.webp'))
# Out:
# LOTii58972 EXP03/22
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []

# %%
print(ExtractDetails('sample25.png'))
# Out:
# Ciplox 100 Tab M.R.P. : 150 Batch No. : BBCIZSBBC Exp. Date : 10-2024 Ciproﬂoxacin 10001
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['Exp. Date : 10-2024']
# ['Exp. Date : 10-2024']
